# %%
from pymongo import MongoClient, TEXT
from collections import Counter


MONGO_URL = 'mongodb://viral:ViralViral@ds011218.mongolab.com:11218/all_recipes'

client = MongoClient(MONGO_URL)
db = client.get_default_database()
collection = db['recipes']

# %%
ingeredient_collection_name = 'ingredients'
cursor = collection.aggregate(
        [
            {"$unwind": "$ingredients"},
            {"$group": {
                "_id": "$ingredients.ingredientID",
                "count": {"$sum":1},
                #"words": {"$addToSet":"$ingredients.displayValue"}
            }}
        ]
)
count_ing = 0
for doc in cursor:
    print doc
    count_ing+=1
print count_ing
# Out:
# {u'count': 1, u'_id': 15398, u'words': [u'1 (15.25 ounce) can vegetarian chili']}
# {u'count': 1, u'_id': 21854, u'words': [u'1 1/2 cups cinnamon graham cracker crumbs']}
# {u'count': 1, u'_id': 9426, u'words': [u'8 ounces honey ham, chopped']}
# {u'count': 1, u'_id': 4521, u'words': [u'2 (10 ounce) packages frozen chopped spinach, cooked']}
# {u'count': 1, u'_id': 21012, u'words': [u'3 tablespoons turkey drippings']}
# {u'count': 1, u'_id': 22880, u'words': [u'2 tablespoons wasabi paste']}
# {u'count': 1, u'_id': 20792, u'words': [u'6 sheets nori (dry seaweed)']}
# {u'count': 1, u'_id': 2684, u'words': [u'2 (8 ounce) cans oysters, liquid reserved']}
# {u'count': 1, u'_id': 13609, u'words': [u'1/2 cup hot taco sauce']}
# {u'count': 1, u'_id': 9031, u'words': [u'1 unsweetened cherry flavored drink mix powder']}
# {u'count': 1, u'_id': 13791, u'words': [u'15 ounces nacho cheese dip']}
# {u'count': 1, u'_id': 5825, u'words': [u'2 frankfurters, sliced']}
# ...
